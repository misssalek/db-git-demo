-- %%
create table if not exists gizmobox.bronze.refunds ()
using delta 
options (
  URL 'jdbc:sqlserver://gizmobox-srv-zs.database.windows.net:1433;database=gizmobox-db',
  dbtable 'refunds',
  user 'misssalek',
  password 'Zs@1199885691'
)
--Show database connection strings
-- test

-- %%
CREATE TABLE IF NOT EXISTS gizmobox.bronze.refunds
USING DELTA;

INSERT INTO gizmobox.bronze.refunds
SELECT *
FROM jdbc(
  'jdbc:sqlserver://gizmobox-srv-zs.database.windows.net:1433;database=gizmobox-db',
  'refunds',
  'misssalek',
  'Zs@1199885691'
);

-- %%
drop table if exists gizmobox.bronze.refunds
