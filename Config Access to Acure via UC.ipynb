# %% [markdown]
# # Access Azure Cloude storage

# %%
# %fs ls 'abfss://demo@daecourseexdl.dfs.core.windows.net/'

# %%
# %sql
create external location if not exists dea_course_ext_dl_demo
url 'abfss://demo@daecourseexdl.dfs.core.windows.net/'
with (storage credential dea_course_sc)
